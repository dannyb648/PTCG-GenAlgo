# %% [markdown]
# # Pokémon TCG AI Battle Challenge - Native Simulation
#
# This notebook installs the required dependencies and runs the native `cabt` simulation on Google Colab's Linux backend.

# %% [markdown]
# ## 1. Install Dependencies
#
# Install `kaggle-environments` which includes the native `cabt` game simulator.

# %%
# !pip install kaggle-environments

# %% [markdown]
# ## 2. Clone/Update Codebase
#
# Clone the repository if it's not already present, or pull the latest changes.

# %%
import os
if not os.path.exists('/content/PTCG-GenAlgo'):
    # !git clone https://github.com/dannyb648/PTCG-GenAlgo.git /content/PTCG-GenAlgo
    # %cd /content/PTCG-GenAlgo
else:
    # %cd /content/PTCG-GenAlgo
    # !git pull

# %% [markdown]
# ## 3. Run Simulation
#
# Run the simulation. Since Colab runs on x86_64 Linux, `kaggle_environments` will successfully load the native `cabt` engine binary (`libcg.so`).

# %%
# !python run_simulation.py
